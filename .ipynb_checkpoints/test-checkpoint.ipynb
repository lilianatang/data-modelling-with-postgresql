# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays WHERE COALESCE(artist_id, '') <> '';
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(4627, 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', datetime.datetime(2018, 11, 21, 21, 56, 47, 796000), 15, 'AR5KOSW1187FB35FF4', 'SOZCTXZ12AB0182364', 'paid')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(8, 'Kaylee', 'Summers', 'F', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 0, Decimal('218.93179'), 'ARD7TVE1187B99BFB1'),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 1969, Decimal('148.03546'), 'ARMJAGH1187FB546F3'),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 0, Decimal('177.47546'), 'ARKRRTF1187B9984DA'),
#  ('SONHOTT12A8C13493C', 'Something Girls', 1982, Decimal('233.40363'), 'AR7G5I41187FB4CE6C'),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 2007, Decimal('209.60608'), 'ARXR32B1187FB57099')]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', Decimal('35.14968'), Decimal('-90.04892')),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', Decimal('NaN'), Decimal('NaN')),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', Decimal('NaN'), Decimal('NaN')),
#  ('ARXR32B1187FB57099', 'Gob', '', Decimal('NaN'), Decimal('NaN'))]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1541106106796, 21, 1, 44, 11, 2018, 3),
#  (1541106352796, 21, 1, 44, 11, 2018, 3),
#  (1541106496796, 21, 1, 44, 11, 2018, 3),
#  (1541106673796, 21, 1, 44, 11, 2018, 3),
#  (1541107053796, 21, 1, 44, 11, 2018, 3)]

# %%
# %sql SELECT * FROM songs JOIN artists ON artists.artist_id = songs.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 75 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 0, Decimal('218.93179'), 'ARD7TVE1187B99BFB1', 'ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 0, Decimal('218.93179'), 'ARD7TVE1187B99BFB1', 'ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 1969, Decimal('148.03546'), 'ARMJAGH1187FB546F3', 'ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', Decimal('35.14968'), Decimal('-90.04892')),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 0, Decimal('177.47546'), 'ARKRRTF1187B9984DA', 'ARKRRTF1187B9984DA', 'Sonora Santanera', '', Decimal('NaN'), Decimal('NaN')),
#  ('SONHOTT12A8C13493C', 'Something Girls', 1982, Decimal('233.40363'), 'AR7G5I41187FB4CE6C', 'AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', Decimal('NaN'), Decimal('NaN')),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 2007, Decimal('209.60608'), 'ARXR32B1187FB57099', 'ARXR32B1187FB57099', 'Gob', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 0, Decimal('267.7024'), 'ARKFYS91187B98E58F', 'ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 0, Decimal('114.78159'), 'ARD0S291187B9B7BF5', 'ARD0S291187B9B7BF5', 'Rated R', 'Ohio', Decimal('NaN'), Decimal('NaN')),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 0, Decimal('189.57016'), 'AR10USD1187B99F3F1', 'AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', Decimal('NaN'), Decimal('NaN')),
#  ('SOIAZJW12AB01853F1', 'Pink World', 1984, Decimal('269.81832'), 'AR8ZCNI1187B9A069B', 'AR8ZCNI1187B9A069B', 'Planet P Project', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 0, Decimal('266.39628'), 'ARNTLGG11E2835DDB9', 'ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 0, Decimal('266.39628'), 'ARNTLGG11E2835DDB9', 'ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 0, Decimal('218.77506'), 'ARGSJW91187B9B1D6B', 'ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', Decimal('35.21962'), Decimal('-80.01955')),
#  ('SOKEJEJ12A8C13E0D0', 'The Urgency (LP Version)', 0, Decimal('245.21098'), 'ARC43071187B990240', 'ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', Decimal('NaN'), Decimal('NaN')),
#  ('SOMUYGI12AB0188633', 'La Culpa', 0, Decimal('226.35057'), 'ARL7K851187B99ACD2', 'ARL7K851187B99ACD2', 'Andy Andy', '', Decimal('NaN'), Decimal('NaN')),
#  ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 0, Decimal('191.84281'), 'ARHHO3O1187B989413', 'ARHHO3O1187B989413', 'Bob Azzam', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 1986, Decimal('307.3824'), 'ARIK43K1187B9AE54C', 'ARIK43K1187B9AE54C', 'Lionel Richie', 'Beverly Hills, CA', Decimal('NaN'), Decimal('NaN')),
#  ('SOHUOAP12A8AE488E9', 'Floating', 1987, Decimal('491.12771'), 'ARD842G1187B997376', 'ARD842G1187B997376', 'Blue Rodeo', 'Toronto, Ontario, Canada', Decimal('43.64856'), Decimal('-79.38533')),
#  ('SOUQQEA12A8C134B1B', 'High Tide', 0, Decimal('228.5971'), 'ARIG6O41187B988BDD', 'ARIG6O41187B988BDD', 'Richard Souther', 'United States', Decimal('37.16793'), Decimal('-95.84502')),
#  ('SOILPQQ12AB017E82A', 'Sohna Nee Sohna Data', 0, Decimal('599.24853'), 'AR1ZHYZ1187FB3C717', 'AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOXLBJT12A8C140925', 'Caught In A Dream', 2004, Decimal('290.29832'), 'ARYKCQI1187FB3B18F', 'ARYKCQI1187FB3B18F', 'Tesla', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOZVMJI12AB01808AF', 'Synthetic Dream', 0, Decimal('165.69424'), 'ARNPAGP1241B9C7FD4', 'ARNPAGP1241B9C7FD4', 'lextrical', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOWTBJW12AC468AC6E', 'Broken-Down Merry-Go-Round', 0, Decimal('151.84934'), 'ARQGYP71187FB44566', 'ARQGYP71187FB44566', 'Jimmy Wakely', 'Mineola, AR', Decimal('34.31109'), Decimal('-94.02978')),
#  ('SOBEBDG12A58A76D60', 'Kassie Jones', 0, Decimal('220.78649'), 'ARI3BMM1187FB4255E', 'ARI3BMM1187FB4255E', 'Alice Stuart', 'Washington', Decimal('38.8991'), Decimal('-77.029')),
#  ('SOZCTXZ12AB0182364', 'Setanta matins', 0, Decimal('269.58322'), 'AR5KOSW1187FB35FF4', 'AR5KOSW1187FB35FF4', 'Elena', 'Dubai UAE', Decimal('49.80388'), Decimal('15.47491')),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 2004, Decimal('207.77751'), 'ARMAC4T1187FB3FA4C', 'ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan', 'Morris Plains, NJ', Decimal('40.82624'), Decimal('-74.47995')),
#  ('SOBLGCN12AB0183212', 'James (Hold The Ladder Steady)', 1985, Decimal('124.86485'), 'AR47JEX1187B995D81', 'AR47JEX1187B995D81', 'SUE THOMPSON', 'Nevada, MO', Decimal('37.83721'), Decimal('-94.35868')),
#  ('SOPSWQW12A6D4F8781', 'Made Like This (Live)', 0, Decimal('225.09669'), 'ARGIWFO1187B9B55B7', 'ARGIWFO1187B9B55B7', 'Five Bolt Main', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOZQDIU12A58A7BCF6', 'Superconfidential', 0, Decimal('338.31138'), 'ARNTLGG11E2835DDB9', 'ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOZQDIU12A58A7BCF6', 'Superconfidential', 0, Decimal('338.31138'), 'ARNTLGG11E2835DDB9', 'ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN')),
#  ('SONYPOM12A8C13B2D7', 'I Think My Wife Is Running Around On Me (Taco Hell)', 2005, Decimal('186.48771'), 'ARDNS031187B9924F0', 'ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', Decimal('32.67828'), Decimal('-83.22295')),
#  ('SOBZBAZ12A6D4F8742', 'Spanish Grease', 1997, Decimal('168.25424'), 'AROUOZZ1187B9ABE51', 'AROUOZZ1187B9ABE51', 'Willie Bobo', 'New York, NY [Spanish Harlem]', Decimal('40.79195'), Decimal('-73.94512')),
#  ('SOVYKGO12AB0187199', 'Crazy Mixed Up World', 1961, Decimal('156.39465'), 'ARH4Z031187B9A71F2', 'ARH4Z031187B9A71F2', 'Faye Adams', 'Newark, NJ', Decimal('40.73197'), Decimal('-74.17418')),
#  ('SOGNCJP12A58A80271', 'Do You Finally Need A Friend', 1972, Decimal('342.56934'), 'ARB29H41187B98F0EF', 'ARB29H41187B98F0EF', 'Terry Callier', 'Chicago', Decimal('41.88415'), Decimal('-87.63241')),
#  ('SOLLHMX12AB01846DC', 'The Emperor Falls', 0, Decimal('484.62322'), 'AR1Y2PT1187FB5B9CE', 'AR1Y2PT1187FB5B9CE', 'John Wesley', 'Brandon', Decimal('27.94017'), Decimal('-82.32547')),
#  ('SOYTPEP12AB0180E7B', 'Twist and Shout', 1964, Decimal('164.80608'), 'ARAJPHH1187FB5566A', 'ARAJPHH1187FB5566A', 'The Shangri-Las', 'Queens, NY', Decimal('40.7038'), Decimal('-73.83168')),
#  ('SOGXHEG12AB018653E', 'It Makes No Difference Now', 1992, Decimal('133.32853'), 'AR0RCMP1187FB3F427', 'AR0RCMP1187FB3F427', 'Billie Jo Spears', 'Beaumont, TX', Decimal('30.08615'), Decimal('-94.10158')),
#  ('SOOLYAZ12A6701F4A6', 'Laws Patrolling (Album Version)', 0, Decimal('173.66159'), 'AREBBGV1187FB523D2', 'AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 'Houston, TX', Decimal('NaN'), Decimal('NaN')),
#  ('SOGOSOV12AF72A285E', '¿Dónde va Chichi?', 1997, Decimal('313.12934'), 'ARGUVEV1187B98BA17', 'ARGUVEV1187B98BA17', 'Sierra Maestra', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOQLGFP12A58A7800E', 'OAKtown', 0, Decimal('259.44771'), 'ARD7TVE1187B99BFB1', 'ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('SOQLGFP12A58A7800E', 'OAKtown', 0, Decimal('259.44771'), 'ARD7TVE1187B99BFB1', 'ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('SOPVXLX12A8C1402D5', 'Larger Than Life', 1999, Decimal('236.25098'), 'AR3JMC51187B9AE49D', 'AR3JMC51187B9AE49D', 'Backstreet Boys', 'Orlando, FL', Decimal('28.53823'), Decimal('-81.37739')),
#  ('SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 2000, Decimal('43.36281'), 'ARPBNLO1187FB3D52F', 'ARPBNLO1187FB3D52F', 'Tiny Tim', 'New York, NY', Decimal('40.71455'), Decimal('-74.00712')),
#  ('SOZHPGD12A8C1394FE', 'Baby Come To Me', 0, Decimal('236.93016'), 'AR9AWNF1187B9AB0B4', 'AR9AWNF1187B9AB0B4', 'Kenny G featuring Daryl Hall', 'Seattle, Washington USA', Decimal('NaN'), Decimal('NaN')),
#  ('SOSLAVG12A8C13397F', 'Den Pai Alo', 0, Decimal('243.82649'), 'AROGWRA122988FEE45', 'AROGWRA122988FEE45', 'Christos Dantis', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOTTDKS12AB018D69B', 'It Wont Be Christmas', 0, Decimal('241.47546'), 'ARMBR4Y1187B9990EB', 'ARMBR4Y1187B9990EB', 'David Martin', 'California - SF', Decimal('37.77916'), Decimal('-122.42005')),
#  ('SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 0, Decimal('183.17016'), 'ARQ9BO41187FB5CF1F', 'ARQ9BO41187FB5CF1F', 'John Davis', 'Pennsylvania', Decimal('40.99471'), Decimal('-77.60454')),
#  ('SOQVMXR12A81C21483', 'Salt In NYC', 0, Decimal('424.12363'), 'ARKULSX1187FB45F84', 'ARKULSX1187FB45F84', 'Trafik', 'Utah', Decimal('39.49974'), Decimal('-111.54732')),
#  ('SODUJBS12A8C132150', 'Wessex Loses a Bride', 0, Decimal('111.62077'), 'ARI2JSK1187FB496EF', 'ARI2JSK1187FB496EF', 'Nick Ingman;Gavyn Wright', 'London, England', Decimal('51.50632'), Decimal('-0.12714')),
#  ('SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 0, Decimal('138.63138'), 'AREDBBQ1187B98AFF5', 'AREDBBQ1187B98AFF5', 'Eddie Calvert', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOTUKVB12AB0181477', 'Blessed Assurance', 1993, Decimal('270.602'), 'AR7ZKHQ1187B98DD73', 'AR7ZKHQ1187B98DD73', 'Glad', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOOJPRH12A8C141995', 'Loaded Like A Gun', 0, Decimal('173.19138'), 'ARBGXIG122988F409D', 'ARBGXIG122988F409D', 'Steel Rain', 'California - SF', Decimal('37.77916'), Decimal('-122.42005')),
#  ('SOBCOSW12A8C13D398', 'Rumba De Barcelona', 0, Decimal('218.38322'), 'AR7SMBG1187B9B9066', 'AR7SMBG1187B9B9066', 'Los Manolos', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 0, Decimal('153.33832'), 'ARGCY1Y1187B9A4FA5', 'ARGCY1Y1187B9A4FA5', 'Gloriana', 'Nashville, TN.', Decimal('36.16778'), Decimal('-86.77836')),
#  ('SOBKWDJ12A8C13B2F3', 'Wild Rose (Back 2 Basics Mix)', 0, Decimal('230.71302'), 'AR36F9J1187FB406F1', 'AR36F9J1187FB406F1', 'Bombay Rockers', 'Denmark', Decimal('56.27609'), Decimal('9.51695')),
#  ('SOFNOQK12AB01840FC', 'Kutt Free (DJ Volume Remix)', 0, Decimal('407.37914'), 'ARNNKDK1187B98BBD5', 'ARNNKDK1187B98BBD5', 'Jinx', 'Zagreb Croatia', Decimal('45.80726'), Decimal('15.967600000000001')),
#  ('SOGVQGJ12AB017F169', 'Ten Tonne', 2005, Decimal('337.68444'), 'AR62SOJ1187FB47BB5', 'AR62SOJ1187FB47BB5', 'Chase & Status', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOFFKZS12AB017F194', 'A Higher Place (Album Version)', 1994, Decimal('236.17261'), 'ARBEBBY1187B9B43DB', 'ARBEBBY1187B9B43DB', 'Tom Petty', 'Gainesville, FL', Decimal('NaN'), Decimal('NaN')),
#  ('SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 0, Decimal('511.16363'), 'ARDR4AC1187FB371A1', 'ARDR4AC1187FB371A1', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOLEYHO12AB0188A85', 'Got My Mojo Workin', 0, Decimal('338.23302'), 'ARAGB2O1187FB3A161', 'ARAGB2O1187FB3A161', 'Pucho & His Latin Soul Brothers', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOPEGZN12AB0181B3D', 'Get Your Head Stuck On Your Neck', 0, Decimal('45.66159'), 'AREDL271187FB40F44', 'AREDL271187FB40F44', 'Soul Mekanik', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOXILUQ12A58A7C72A', 'Jenny Take a Ride', 2004, Decimal('207.43791'), 'ARP6N5A1187B99D1A3', 'ARP6N5A1187B99D1A3', 'Mitch Ryder', 'Hamtramck, MI', Decimal('NaN'), Decimal('NaN')),
#  ('SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 0, Decimal('29.54404'), 'ARGSAFR1269FB35070', 'ARGSAFR1269FB35070', 'Blingtones', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOSWKAV12AB018FC91', 'Midnight Star', 0, Decimal('335.51628'), 'ARULZCI1241B9C8611', 'ARULZCI1241B9C8611', 'Luna Orbit Project', '', Decimal('NaN'), Decimal('NaN')),
#  ('SONSKXP12A8C13A2C9', 'Native Soul', 2003, Decimal('197.19791'), 'AR0IAWL1187B9A96D0', 'AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', Decimal('8.4177'), Decimal('-80.11278')),
#  ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 0, Decimal('152.92036'), 'ARJIE2Y1187B994AB7', 'ARJIE2Y1187B994AB7', 'Line Renaud', '', Decimal('NaN'), Decimal('NaN')),
#  ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 0, Decimal('326.00771'), 'ARLTWXK1187FB5A3F8', 'ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', Decimal('32.74863'), Decimal('-97.32925')),
#  ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 1994, Decimal('305.162'), 'ARNF6401187FB57032', 'ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', Decimal('40.79086'), Decimal('-73.96644')),
#  ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 0, Decimal('279.97995'), 'ARPFHN61187FB575F6', 'ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', Decimal('41.88415'), Decimal('-87.63241')),
#  ('SOLYIBD12A8C135045', 'Music is what we love', 0, Decimal('261.51138'), 'AR051KA1187B98B2FF', 'AR051KA1187B98B2FF', 'Wilks', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOINLJW12A8C13314C', 'City Slickers', 2008, Decimal('149.86404'), 'AR8IEZO1187B99055E', 'AR8IEZO1187B99055E', 'Marc Shaiman', '', Decimal('NaN'), Decimal('NaN')),
#  ('SOGDBUF12A8C140FAA', 'Intro', 2003, Decimal('75.67628'), 'AR558FS1187FB45658', 'AR558FS1187FB45658', '40 Grit', '', Decimal('NaN'), Decimal('NaN')),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 2004, Decimal('290.55955'), 'ARVBRGZ1187FB4675A', 'ARVBRGZ1187FB4675A', 'Gwen Stefani', '', Decimal('NaN'), Decimal('NaN')),
#  ('SODAUVL12A8C13D184', 'Prognosis', 2000, Decimal('363.85914'), 'ARWB3G61187FB49404', 'ARWB3G61187FB49404', 'Steve Morse', 'Hamilton, Ohio', Decimal('NaN'), Decimal('NaN')),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 0, Decimal('282.43546'), 'AREVWGE1187B9B890A', 'AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', Decimal('-13.442'), Decimal('-41.9952'))]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
import glob
import psycopg2
import pandas as pd
import json
import datetime
import numpy as np
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()
cur.execute("SELECT songs.song_id, songs.artist_id FROM songs JOIN artists ON artists.artist_id = songs.artist_id WHERE title = %s AND name = %s AND duration = %s;", ("I Didn't Mean To","Casual", 218.93179))
cur.fetchone()
# Out:
# ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1')
